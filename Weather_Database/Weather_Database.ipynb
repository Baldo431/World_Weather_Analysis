# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import requests
import time
from citipy import citipy
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Build the base url.
geocode_base_url = 'https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=' + weather_api_key 

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = geocode_base_url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather['weather'][0]['description']
      
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 1 | faya
# Processing Record 3 of Set 1 | meulaboh
# Processing Record 4 of Set 1 | kinston
# Processing Record 5 of Set 1 | pisco
# Processing Record 6 of Set 1 | henties bay
# Processing Record 7 of Set 1 | cabo san lucas
# Processing Record 8 of Set 1 | provideniya
# Processing Record 9 of Set 1 | teluk intan
# Processing Record 10 of Set 1 | chokurdakh
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | dingle
# Processing Record 13 of Set 1 | upernavik
# Processing Record 14 of Set 1 | nikolskoye
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | luderitz
# Processing Record 18 of Set 1 | cherskiy
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | bambous virieux
# Processing Record 23 of Set 1 | danshui
# Processing Record 24 of Set 1 | arraial do cabo
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | tessalit
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | tuktoyaktuk
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | chazuta
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | ahipara
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | lesnoye
# Processing Record 37 of Set 1 | qaanaaq
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | hibbing
# Processing Record 40 of Set 1 | tasiilaq
# Processing Record 41 of Set 1 | mount gambier
# Processing Record 42 of Set 1 | poum
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | tiksi
# Processing Record 45 of Set 1 | dalby
# Processing Record 46 of Set 1 | new norfolk
# Processing Record 47 of Set 1 | mahon
# Processing Record 48 of Set 1 | mazagao
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | nanortalik
# Processing Record 1 of Set 2 | talnakh
# Processing Record 2 of Set 2 | sao joao da barra
# Processing Record 3 of Set 2 | norman wells
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | cirpan
# City not found. Skipping...
# Processing Record 6 of Set 2 | mizan teferi
# Processing Record 7 of Set 2 | ozgon
# City not found. Skipping...
# Processing Record 8 of Set 2 | half moon bay
# Processing Record 9 of Set 2 | nuevo progreso
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | san patricio
# Processing Record 12 of Set 2 | touros
# Processing Record 13 of Set 2 | wloclawek
# Processing Record 14 of Set 2 | angoche
# Processing Record 15 of Set 2 | kahului
# Processing Record 16 of Set 2 | longyearbyen
# Processing Record 17 of Set 2 | saint-philippe
# Processing Record 18 of Set 2 | batagay-alyta
# Processing Record 19 of Set 2 | lorengau
# Processing Record 20 of Set 2 | kushiro
# Processing Record 21 of Set 2 | butaritari
# Processing Record 22 of Set 2 | elat
# Processing Record 23 of Set 2 | grindavik
# Processing Record 24 of Set 2 | tuy hoa
# Processing Record 25 of Set 2 | farah
# Processing Record 26 of Set 2 | coquimbo
# Processing Record 27 of Set 2 | rikitea
# Processing Record 28 of Set 2 | puerto ayora
# Processing Record 29 of Set 2 | college
# Processing Record 30 of Set 2 | east london
# Processing Record 31 of Set 2 | puyo
# Processing Record 32 of Set 2 | geraldton
# Processing Record 33 of Set 2 | thiruvananthapuram
# Processing Record 34 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 2 | zemio
# Processing Record 37 of Set 2 | hami
# Processing Record 38 of Set 2 | saskylakh
# Processing Record 39 of Set 2 | port elizabeth
# Processing Record 40 of Set 2 | vega de alatorre
# Processing Record 41 of Set 2 | tuatapere
# Processing Record 42 of Set 2 | clyde river
# Processing Record 43 of Set 2 | mende
# Processing Record 44 of Set 2 | altamont
# Processing Record 45 of Set 2 | grants pass
# Processing Record 46 of Set 2 | champerico
# Processing Record 47 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 2 | lavrentiya
# Processing Record 49 of Set 2 | mandera
# Processing Record 50 of Set 2 | daxian
# City not found. Skipping...
# Processing Record 1 of Set 3 | fortuna
# Processing Record 2 of Set 3 | fagernes
# Processing Record 3 of Set 3 | northam
# Processing Record 4 of Set 3 | lata
# Processing Record 5 of Set 3 | vila velha
# Processing Record 6 of Set 3 | bengkulu
# Processing Record 7 of Set 3 | huambo
# Processing Record 8 of Set 3 | pedernales
# Processing Record 9 of Set 3 | ribeira grande
# Processing Record 10 of Set 3 | bluff
# Processing Record 11 of Set 3 | bubaque
# Processing Record 12 of Set 3 | yellowknife
# Processing Record 13 of Set 3 | chicama
# Processing Record 14 of Set 3 | mount isa
# Processing Record 15 of Set 3 | necochea
# Processing Record 16 of Set 3 | otukpo
# Processing Record 17 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 3 | chiang khong
# Processing Record 19 of Set 3 | nabire
# Processing Record 20 of Set 3 | singapore
# Processing Record 21 of Set 3 | georgetown
# Processing Record 22 of Set 3 | havre-saint-pierre
# Processing Record 23 of Set 3 | gat
# Processing Record 24 of Set 3 | condoto
# Processing Record 25 of Set 3 | jamestown
# Processing Record 26 of Set 3 | lebu
# Processing Record 27 of Set 3 | esperance
# Processing Record 28 of Set 3 | cody
# Processing Record 29 of Set 3 | verkhnevilyuysk
# Processing Record 30 of Set 3 | sri aman
# Processing Record 31 of Set 3 | port-gentil
# Processing Record 32 of Set 3 | launceston
# Processing Record 33 of Set 3 | pevek
# Processing Record 34 of Set 3 | ilam
# Processing Record 35 of Set 3 | bredasdorp
# Processing Record 36 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 3 | lac du bonnet
# Processing Record 38 of Set 3 | saint-augustin
# Processing Record 39 of Set 3 | mehamn
# Processing Record 40 of Set 3 | tateyama
# Processing Record 41 of Set 3 | kavieng
# Processing Record 42 of Set 3 | srednekolymsk
# Processing Record 43 of Set 3 | portland
# Processing Record 44 of Set 3 | barrow
# Processing Record 45 of Set 3 | olimpia
# Processing Record 46 of Set 3 | batemans bay
# Processing Record 47 of Set 3 | young
# Processing Record 48 of Set 3 | saint george
# Processing Record 49 of Set 3 | ardatov
# Processing Record 50 of Set 3 | bethel
# Processing Record 1 of Set 4 | carnarvon
# Processing Record 2 of Set 4 | port alfred
# Processing Record 3 of Set 4 | evensk
# Processing Record 4 of Set 4 | husavik
# Processing Record 5 of Set 4 | lagoa
# Processing Record 6 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 7 of Set 4 | chara
# Processing Record 8 of Set 4 | isangel
# Processing Record 9 of Set 4 | caravelas
# Processing Record 10 of Set 4 | dhandhuka
# Processing Record 11 of Set 4 | bolkhov
# Processing Record 12 of Set 4 | charters towers
# Processing Record 13 of Set 4 | bathsheba
# Processing Record 14 of Set 4 | quatre cocos
# Processing Record 15 of Set 4 | revelstoke
# Processing Record 16 of Set 4 | bayanday
# Processing Record 17 of Set 4 | ponta do sol
# Processing Record 18 of Set 4 | bardiyah
# Processing Record 19 of Set 4 | hundested
# Processing Record 20 of Set 4 | kalmunai
# Processing Record 21 of Set 4 | keshan
# City not found. Skipping...
# Processing Record 22 of Set 4 | san cristobal
# Processing Record 23 of Set 4 | constitucion
# Processing Record 24 of Set 4 | mecca
# Processing Record 25 of Set 4 | tampin
# Processing Record 26 of Set 4 | paamiut
# Processing Record 27 of Set 4 | rolim de moura
# City not found. Skipping...
# Processing Record 28 of Set 4 | morbegno
# Processing Record 29 of Set 4 | bay roberts
# Processing Record 30 of Set 4 | lakatoro
# Processing Record 31 of Set 4 | mayo
# Processing Record 32 of Set 4 | mandurah
# Processing Record 33 of Set 4 | mansa
# Processing Record 34 of Set 4 | malakal
# Processing Record 35 of Set 4 | kolyvan
# Processing Record 36 of Set 4 | jarvakandi
# Processing Record 37 of Set 4 | khatanga
# Processing Record 38 of Set 4 | katobu
# Processing Record 39 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 4 | alamosa
# Processing Record 41 of Set 4 | mincivan
# Processing Record 42 of Set 4 | chifeng
# Processing Record 43 of Set 4 | guayaramerin
# Processing Record 44 of Set 4 | black diamond
# Processing Record 45 of Set 4 | perpignan
# Processing Record 46 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 47 of Set 4 | nizhniy kuranakh
# Processing Record 48 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 4 | verkhnechusovskiye gorodki
# Processing Record 50 of Set 4 | carutapera
# Processing Record 1 of Set 5 | dibulla
# Processing Record 2 of Set 5 | san quintin
# Processing Record 3 of Set 5 | jacqueville
# Processing Record 4 of Set 5 | wanning
# Processing Record 5 of Set 5 | baykit
# Processing Record 6 of Set 5 | yulara
# Processing Record 7 of Set 5 | sisimiut
# Processing Record 8 of Set 5 | mikuni
# Processing Record 9 of Set 5 | smithers
# Processing Record 10 of Set 5 | onega
# Processing Record 11 of Set 5 | cadillac
# Processing Record 12 of Set 5 | gwadar
# Processing Record 13 of Set 5 | pinawa
# Processing Record 14 of Set 5 | dikson
# Processing Record 15 of Set 5 | palmas
# Processing Record 16 of Set 5 | manokwari
# Processing Record 17 of Set 5 | muravlenko
# Processing Record 18 of Set 5 | kathu
# Processing Record 19 of Set 5 | faanui
# Processing Record 20 of Set 5 | jining
# Processing Record 21 of Set 5 | iqaluit
# Processing Record 22 of Set 5 | acapulco
# Processing Record 23 of Set 5 | okhotsk
# Processing Record 24 of Set 5 | san lorenzo
# Processing Record 25 of Set 5 | opuwo
# Processing Record 26 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 5 | hualmay
# Processing Record 28 of Set 5 | dianopolis
# City not found. Skipping...
# Processing Record 29 of Set 5 | sinnamary
# Processing Record 30 of Set 5 | port hardy
# Processing Record 31 of Set 5 | hovd
# Processing Record 32 of Set 5 | vikulovo
# Processing Record 33 of Set 5 | sao filipe
# Processing Record 34 of Set 5 | marystown
# Processing Record 35 of Set 5 | matadi
# Processing Record 36 of Set 5 | awjilah
# Processing Record 37 of Set 5 | ventspils
# Processing Record 38 of Set 5 | mudyuga
# City not found. Skipping...
# Processing Record 39 of Set 5 | kargasok
# Processing Record 40 of Set 5 | vung tau
# Processing Record 41 of Set 5 | mahebourg
# Processing Record 42 of Set 5 | baoqing
# Processing Record 43 of Set 5 | mackay
# Processing Record 44 of Set 5 | chernoyerkovskaya
# Processing Record 45 of Set 5 | negombo
# Processing Record 46 of Set 5 | sunyani
# Processing Record 47 of Set 5 | laguna
# Processing Record 48 of Set 5 | tonantins
# Processing Record 49 of Set 5 | verkh-usugli
# Processing Record 50 of Set 5 | mitsamiouli
# Processing Record 1 of Set 6 | cidreira
# Processing Record 2 of Set 6 | roald
# Processing Record 3 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 6 | teguise
# Processing Record 5 of Set 6 | humaita
# Processing Record 6 of Set 6 | severo-kurilsk
# Processing Record 7 of Set 6 | helong
# Processing Record 8 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 6 | ilulissat
# Processing Record 10 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 6 | cairns
# Processing Record 12 of Set 6 | samarai
# Processing Record 13 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 15 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 6 | belaya gora
# Processing Record 18 of Set 6 | ancud
# Processing Record 19 of Set 6 | sorland
# Processing Record 20 of Set 6 | nantucket
# Processing Record 21 of Set 6 | weiser
# Processing Record 22 of Set 6 | prainha
# Processing Record 23 of Set 6 | bria
# Processing Record 24 of Set 6 | daru
# Processing Record 25 of Set 6 | acari
# Processing Record 26 of Set 6 | alekseyevsk
# Processing Record 27 of Set 6 | gushikawa
# Processing Record 28 of Set 6 | diffa
# Processing Record 29 of Set 6 | pangnirtung
# Processing Record 30 of Set 6 | wajir
# Processing Record 31 of Set 6 | sobolevo
# Processing Record 32 of Set 6 | mildura
# Processing Record 33 of Set 6 | hirna
# Processing Record 34 of Set 6 | katsuura
# Processing Record 35 of Set 6 | bongandanga
# Processing Record 36 of Set 6 | kandrian
# Processing Record 37 of Set 6 | tautira
# Processing Record 38 of Set 6 | kiama
# Processing Record 39 of Set 6 | barentu
# Processing Record 40 of Set 6 | thompson
# Processing Record 41 of Set 6 | matamoros
# Processing Record 42 of Set 6 | bodden town
# Processing Record 43 of Set 6 | westport
# Processing Record 44 of Set 6 | codrington
# Processing Record 45 of Set 6 | burica
# City not found. Skipping...
# Processing Record 46 of Set 6 | victoria
# Processing Record 47 of Set 6 | vanavara
# Processing Record 48 of Set 6 | ambatofinandrahana
# Processing Record 49 of Set 6 | beyneu
# Processing Record 50 of Set 6 | santiago de chuco
# Processing Record 1 of Set 7 | dryden
# Processing Record 2 of Set 7 | kawalu
# Processing Record 3 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 7 | vredendal
# Processing Record 5 of Set 7 | azul
# Processing Record 6 of Set 7 | visnes
# Processing Record 7 of Set 7 | port lincoln
# Processing Record 8 of Set 7 | saint-gabriel
# Processing Record 9 of Set 7 | itarema
# Processing Record 10 of Set 7 | hasaki
# Processing Record 11 of Set 7 | kirkuk
# Processing Record 12 of Set 7 | yunjinghong
# City not found. Skipping...
# Processing Record 13 of Set 7 | kuala pilah
# Processing Record 14 of Set 7 | moranbah
# Processing Record 15 of Set 7 | yarim
# Processing Record 16 of Set 7 | khartoum
# Processing Record 17 of Set 7 | umm kaddadah
# Processing Record 18 of Set 7 | cassia
# Processing Record 19 of Set 7 | nadym
# Processing Record 20 of Set 7 | pingzhuang
# Processing Record 21 of Set 7 | vanimo
# Processing Record 22 of Set 7 | senmonorom
# City not found. Skipping...
# Processing Record 23 of Set 7 | thinadhoo
# Processing Record 24 of Set 7 | coihaique
# Processing Record 25 of Set 7 | sitka
# Processing Record 26 of Set 7 | margate
# Processing Record 27 of Set 7 | ames
# Processing Record 28 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 29 of Set 7 | leh
# Processing Record 30 of Set 7 | staropesterevo
# Processing Record 31 of Set 7 | bonavista
# Processing Record 32 of Set 7 | inta
# Processing Record 33 of Set 7 | vila franca do campo
# Processing Record 34 of Set 7 | alma
# Processing Record 35 of Set 7 | valdivia
# Processing Record 36 of Set 7 | olinda
# Processing Record 37 of Set 7 | hamilton
# Processing Record 38 of Set 7 | puerto madryn
# Processing Record 39 of Set 7 | ucluelet
# Processing Record 40 of Set 7 | padang
# Processing Record 41 of Set 7 | labuhan
# Processing Record 42 of Set 7 | nuuk
# Processing Record 43 of Set 7 | taltal
# Processing Record 44 of Set 7 | bundaberg
# Processing Record 45 of Set 7 | road town
# Processing Record 46 of Set 7 | jiuquan
# Processing Record 47 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 48 of Set 7 | zuwarah
# Processing Record 49 of Set 7 | batouri
# Processing Record 50 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 8 | skjervoy
# Processing Record 2 of Set 8 | tecoanapa
# Processing Record 3 of Set 8 | yar-sale
# Processing Record 4 of Set 8 | vadso
# Processing Record 5 of Set 8 | progreso
# Processing Record 6 of Set 8 | burpengary
# Processing Record 7 of Set 8 | collipulli
# Processing Record 8 of Set 8 | quang ngai
# Processing Record 9 of Set 8 | sioux lookout
# Processing Record 10 of Set 8 | los llanos de aridane
# Processing Record 11 of Set 8 | darnah
# Processing Record 12 of Set 8 | araouane
# Processing Record 13 of Set 8 | chuy
# Processing Record 14 of Set 8 | ngorongoro
# Processing Record 15 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 8 | teahupoo
# Processing Record 17 of Set 8 | anloga
# Processing Record 18 of Set 8 | melfi
# Processing Record 19 of Set 8 | yajalon
# Processing Record 20 of Set 8 | isiro
# Processing Record 21 of Set 8 | quelimane
# Processing Record 22 of Set 8 | fort nelson
# Processing Record 23 of Set 8 | las vegas
# Processing Record 24 of Set 8 | tumbagaan
# Processing Record 25 of Set 8 | shimoda
# Processing Record 26 of Set 8 | alta floresta
# Processing Record 27 of Set 8 | seoul
# Processing Record 28 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 8 | ulyanovo
# City not found. Skipping...
# Processing Record 30 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 31 of Set 8 | jijiga
# Processing Record 32 of Set 8 | jega
# Processing Record 33 of Set 8 | puerto baquerizo moreno
# Processing Record 34 of Set 8 | mayskiy
# Processing Record 35 of Set 8 | lichuan
# Processing Record 36 of Set 8 | eureka
# Processing Record 37 of Set 8 | comal
# Processing Record 38 of Set 8 | port-cartier
# Processing Record 39 of Set 8 | kundla
# Processing Record 40 of Set 8 | narsaq
# Processing Record 41 of Set 8 | taoudenni
# Processing Record 42 of Set 8 | devils lake
# Processing Record 43 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 8 | fairbanks
# Processing Record 45 of Set 8 | nkhotakota
# Processing Record 46 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 47 of Set 8 | turukhansk
# Processing Record 48 of Set 8 | dunedin
# Processing Record 49 of Set 8 | singaraja
# Processing Record 50 of Set 8 | conakry
# Processing Record 1 of Set 9 | makakilo city
# Processing Record 2 of Set 9 | camacha
# Processing Record 3 of Set 9 | severnyy
# Processing Record 4 of Set 9 | san jeronimo
# Processing Record 5 of Set 9 | alfenas
# Processing Record 6 of Set 9 | nkoteng
# Processing Record 7 of Set 9 | alice springs
# Processing Record 8 of Set 9 | guerrero negro
# Processing Record 9 of Set 9 | rantauprapat
# Processing Record 10 of Set 9 | the valley
# Processing Record 11 of Set 9 | santa cruz de tenerife
# Processing Record 12 of Set 9 | prince rupert
# Processing Record 13 of Set 9 | sirur
# Processing Record 14 of Set 9 | souillac
# Processing Record 15 of Set 9 | puerto del rosario
# Processing Record 16 of Set 9 | kerrobert
# Processing Record 17 of Set 9 | bandar-e anzali
# Processing Record 18 of Set 9 | tungor
# Processing Record 19 of Set 9 | brufut
# Processing Record 20 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 9 | nakhon phanom
# Processing Record 22 of Set 9 | kodiak
# Processing Record 23 of Set 9 | tilichiki
# Processing Record 24 of Set 9 | pyaozerskiy
# Processing Record 25 of Set 9 | puerto leguizamo
# Processing Record 26 of Set 9 | cockburn town
# Processing Record 27 of Set 9 | voh
# Processing Record 28 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 29 of Set 9 | cayenne
# Processing Record 30 of Set 9 | aksarka
# Processing Record 31 of Set 9 | bilma
# Processing Record 32 of Set 9 | klaksvik
# Processing Record 33 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 9 | tamiahua
# Processing Record 35 of Set 9 | lavumisa
# Processing Record 36 of Set 9 | kusk
# City not found. Skipping...
# Processing Record 37 of Set 9 | onokhoy
# Processing Record 38 of Set 9 | tabuk
# Processing Record 39 of Set 9 | beringovskiy
# Processing Record 40 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 42 of Set 9 | gulshat
# City not found. Skipping...
# Processing Record 43 of Set 9 | coos bay
# Processing Record 44 of Set 9 | marang
# Processing Record 45 of Set 9 | royan
# Processing Record 46 of Set 9 | maine-soroa
# Processing Record 47 of Set 9 | hluti
# Processing Record 48 of Set 9 | dobra
# Processing Record 49 of Set 9 | kuandian
# Processing Record 50 of Set 9 | odienne
# Processing Record 1 of Set 10 | teya
# Processing Record 2 of Set 10 | cikupa
# Processing Record 3 of Set 10 | vardo
# Processing Record 4 of Set 10 | bell ville
# Processing Record 5 of Set 10 | okato
# Processing Record 6 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 10 | toppenish
# Processing Record 8 of Set 10 | berlevag
# Processing Record 9 of Set 10 | arkhangelskoye
# Processing Record 10 of Set 10 | tevriz
# Processing Record 11 of Set 10 | ayan
# Processing Record 12 of Set 10 | chino valley
# Processing Record 13 of Set 10 | el alto
# Processing Record 14 of Set 10 | lucapa
# Processing Record 15 of Set 10 | puerto escondido
# Processing Record 16 of Set 10 | kavaratti
# Processing Record 17 of Set 10 | olafsvik
# Processing Record 18 of Set 10 | buon me thuot
# City not found. Skipping...
# Processing Record 19 of Set 10 | menzelinsk
# Processing Record 20 of Set 10 | nome
# Processing Record 21 of Set 10 | bintulu
# Processing Record 22 of Set 10 | tanabe
# Processing Record 23 of Set 10 | north platte
# Processing Record 24 of Set 10 | high level
# Processing Record 25 of Set 10 | douglas
# Processing Record 26 of Set 10 | vallenar
# Processing Record 27 of Set 10 | taihe
# Processing Record 28 of Set 10 | drayton valley
# Processing Record 29 of Set 10 | tsuyama
# Processing Record 30 of Set 10 | khash
# Processing Record 31 of Set 10 | chapais
# Processing Record 32 of Set 10 | jaumave
# Processing Record 33 of Set 10 | cururupu
# Processing Record 34 of Set 10 | andilamena
# Processing Record 35 of Set 10 | umm lajj
# Processing Record 36 of Set 10 | farafangana
# Processing Record 37 of Set 10 | vestmanna
# Processing Record 38 of Set 10 | mattru
# Processing Record 39 of Set 10 | flinders
# Processing Record 40 of Set 10 | sechura
# Processing Record 41 of Set 10 | ekhabi
# Processing Record 42 of Set 10 | saint anthony
# Processing Record 43 of Set 10 | qasigiannguit
# Processing Record 44 of Set 10 | caraballeda
# Processing Record 45 of Set 10 | deputatskiy
# Processing Record 46 of Set 10 | zhuhai
# Processing Record 47 of Set 10 | kaitangata
# Processing Record 48 of Set 10 | jaisinghnagar
# Processing Record 49 of Set 10 | kabale
# Processing Record 50 of Set 10 | ngawi
# Processing Record 1 of Set 11 | ghanzi
# Processing Record 2 of Set 11 | taksimo
# Processing Record 3 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 4 of Set 11 | iquique
# Processing Record 5 of Set 11 | kutum
# Processing Record 6 of Set 11 | blind river
# Processing Record 7 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 11 | ridgecrest
# Processing Record 9 of Set 11 | san luis
# Processing Record 10 of Set 11 | benguela
# Processing Record 11 of Set 11 | vale
# Processing Record 12 of Set 11 | ust-nera
# Processing Record 13 of Set 11 | mayya
# Processing Record 14 of Set 11 | airai
# Processing Record 15 of Set 11 | paramonga
# Processing Record 16 of Set 11 | verkhoyansk
# Processing Record 17 of Set 11 | ulladulla
# Processing Record 18 of Set 11 | morondava
# Processing Record 19 of Set 11 | villa del rosario
# Processing Record 20 of Set 11 | qaqortoq
# Processing Record 21 of Set 11 | wattegama
# Processing Record 22 of Set 11 | kirkwall
# Processing Record 23 of Set 11 | bendigo
# Processing Record 24 of Set 11 | baishishan
# Processing Record 25 of Set 11 | piacabucu
# Processing Record 26 of Set 11 | isabela
# Processing Record 27 of Set 11 | itamaraca
# Processing Record 28 of Set 11 | glendive
# Processing Record 29 of Set 11 | tura
# Processing Record 30 of Set 11 | adrar
# Processing Record 31 of Set 11 | high prairie
# Processing Record 32 of Set 11 | bilibino
# Processing Record 33 of Set 11 | lima
# Processing Record 34 of Set 11 | rincon
# Processing Record 35 of Set 11 | biak
# Processing Record 36 of Set 11 | mobaye
# Processing Record 37 of Set 11 | kharan
# Processing Record 38 of Set 11 | celestun
# Processing Record 39 of Set 11 | vilhena
# Processing Record 40 of Set 11 | bowen
# Processing Record 41 of Set 11 | yima
# Processing Record 42 of Set 11 | ixtapa
# Processing Record 43 of Set 11 | guarapari
# Processing Record 44 of Set 11 | dicabisagan
# Processing Record 45 of Set 11 | boguchany
# Processing Record 46 of Set 11 | xiongzhou
# Processing Record 47 of Set 11 | imbituba
# Processing Record 48 of Set 11 | rock sound
# Processing Record 49 of Set 11 | dawei
# Processing Record 50 of Set 11 | yenagoa
# Processing Record 1 of Set 12 | broome
# Processing Record 2 of Set 12 | houma
# Processing Record 3 of Set 12 | phrai bung
# City not found. Skipping...
# Processing Record 4 of Set 12 | karratha
# Processing Record 5 of Set 12 | manggar
# Processing Record 6 of Set 12 | ostashkov
# Processing Record 7 of Set 12 | erzin
# Processing Record 8 of Set 12 | bull savanna
# Processing Record 9 of Set 12 | moose factory
# Processing Record 10 of Set 12 | nelipyno
# Processing Record 11 of Set 12 | bafq
# Processing Record 12 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 13 of Set 12 | bud
# Processing Record 14 of Set 12 | bar harbor
# Processing Record 15 of Set 12 | pacific grove
# Processing Record 16 of Set 12 | gizo
# Processing Record 17 of Set 12 | zunyi
# Processing Record 18 of Set 12 | leeton
# Processing Record 19 of Set 12 | ketchikan
# Processing Record 20 of Set 12 | praia da vitoria
# Processing Record 21 of Set 12 | tongliao
# Processing Record 22 of Set 12 | waingapu
# Processing Record 23 of Set 12 | alofi
# Processing Record 24 of Set 12 | chumikan
# Processing Record 25 of Set 12 | abdulino
# Processing Record 26 of Set 12 | mykhaylivka
# Processing Record 27 of Set 12 | luwuk
# Processing Record 28 of Set 12 | gasa
# Processing Record 29 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 30 of Set 12 | san pablo de borbur
# Processing Record 31 of Set 12 | ust-barguzin
# Processing Record 32 of Set 12 | beneditinos
# Processing Record 33 of Set 12 | binzhou
# Processing Record 34 of Set 12 | port hedland
# Processing Record 35 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 36 of Set 12 | yingcheng
# Processing Record 37 of Set 12 | muscat
# Processing Record 38 of Set 12 | hun
# Processing Record 39 of Set 12 | luganville
# Processing Record 40 of Set 12 | amapa
# Processing Record 41 of Set 12 | bellary
# Processing Record 42 of Set 12 | raudeberg
# Processing Record 43 of Set 12 | anadyr
# Processing Record 44 of Set 12 | muros
# Processing Record 45 of Set 12 | rawson
# Processing Record 46 of Set 12 | penzance
# Processing Record 47 of Set 12 | kanigoro
# Processing Record 48 of Set 12 | atasu
# Processing Record 49 of Set 12 | yumen
# Processing Record 50 of Set 12 | mareeba
# Processing Record 1 of Set 13 | harrisburg
# Processing Record 2 of Set 13 | udachnyy
# Processing Record 3 of Set 13 | mgandu
# Processing Record 4 of Set 13 | sola
# Processing Record 5 of Set 13 | avera
# Processing Record 6 of Set 13 | mataram
# Processing Record 7 of Set 13 | ubinskoye
# Processing Record 8 of Set 13 | xacmaz
# Processing Record 9 of Set 13 | yavas
# Processing Record 10 of Set 13 | yuancheng
# Processing Record 11 of Set 13 | namibe
# Processing Record 12 of Set 13 | aleksandrovka
# Processing Record 13 of Set 13 | porto torres
# Processing Record 14 of Set 13 | tevaitoa
# Processing Record 15 of Set 13 | warrington
# Processing Record 16 of Set 13 | mabaruma
# Processing Record 17 of Set 13 | sheridan
# Processing Record 18 of Set 13 | kupang
# Processing Record 19 of Set 13 | aykhal
# Processing Record 20 of Set 13 | jacmel
# Processing Record 21 of Set 13 | kyabe
# Processing Record 22 of Set 13 | gamba
# Processing Record 23 of Set 13 | botou
# Processing Record 24 of Set 13 | lompoc
# Processing Record 25 of Set 13 | manado
# Processing Record 26 of Set 13 | vuktyl
# Processing Record 27 of Set 13 | kampong cham
# Processing Record 28 of Set 13 | tamandare
# Processing Record 29 of Set 13 | gawler
# Processing Record 30 of Set 13 | dali
# Processing Record 31 of Set 13 | sabha
# Processing Record 32 of Set 13 | hobyo
# Processing Record 33 of Set 13 | islaz
# Processing Record 34 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 35 of Set 13 | sokna
# Processing Record 36 of Set 13 | hervey bay
# Processing Record 37 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 38 of Set 13 | zhigalovo
# Processing Record 39 of Set 13 | bayangol
# Processing Record 40 of Set 13 | sakakah
# Processing Record 41 of Set 13 | prieska
# Processing Record 42 of Set 13 | wanaka
# Processing Record 43 of Set 13 | lichinga
# Processing Record 44 of Set 13 | sukhoverkovo
# City not found. Skipping...
# Processing Record 45 of Set 13 | jaguariaiva
# Processing Record 46 of Set 13 | segou
# Processing Record 47 of Set 13 | grand island
# Processing Record 48 of Set 13 | shonguy
# Processing Record 49 of Set 13 | anastacio
# Processing Record 50 of Set 13 | bada
# Processing Record 1 of Set 14 | buriti
# Processing Record 2 of Set 14 | kodinar
# Processing Record 3 of Set 14 | banyo
# Processing Record 4 of Set 14 | zeya
# Processing Record 5 of Set 14 | miri
# Processing Record 6 of Set 14 | porterville
# Processing Record 7 of Set 14 | lukovetskiy
# Processing Record 8 of Set 14 | strezhevoy
# Processing Record 9 of Set 14 | great bend
# Processing Record 10 of Set 14 | nakuru
# Processing Record 11 of Set 14 | zholymbet
# Processing Record 12 of Set 14 | nizhnyaya tavda
# Processing Record 13 of Set 14 | urengoy
# Processing Record 14 of Set 14 | port blair
# Processing Record 15 of Set 14 | pimentel
# Processing Record 16 of Set 14 | la tuque
# Processing Record 17 of Set 14 | khonsa
# Processing Record 18 of Set 14 | taubate
# Processing Record 19 of Set 14 | diamantino
# Processing Record 20 of Set 14 | klyuchi
# Processing Record 21 of Set 14 | hay river
# Processing Record 22 of Set 14 | katete
# Processing Record 23 of Set 14 | cozumel
# Processing Record 24 of Set 14 | micheweni
# Processing Record 25 of Set 14 | forrest city
# Processing Record 26 of Set 14 | epiniana
# Processing Record 27 of Set 14 | kodinsk
# Processing Record 28 of Set 14 | nizhniy odes
# Processing Record 29 of Set 14 | jaisalmer
# Processing Record 30 of Set 14 | oriximina
# Processing Record 31 of Set 14 | maurawan
# Processing Record 32 of Set 14 | goderich
# Processing Record 33 of Set 14 | missoula
# Processing Record 34 of Set 14 | grand gaube
# Processing Record 35 of Set 14 | fianga
# City not found. Skipping...
# Processing Record 36 of Set 14 | glasgow
# Processing Record 37 of Set 14 | talaya
# Processing Record 38 of Set 14 | nouakchott
# Processing Record 39 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 40 of Set 14 | vostok
# Processing Record 41 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 42 of Set 14 | viedma
# Processing Record 43 of Set 14 | kruisfontein
# Processing Record 44 of Set 14 | yakeshi
# Processing Record 45 of Set 14 | baghdad
# Processing Record 46 of Set 14 | heyang
# Processing Record 47 of Set 14 | dongli
# Processing Record 48 of Set 14 | hirara
# Processing Record 49 of Set 14 | ilinskiy
# Processing Record 50 of Set 14 | mount pleasant
# Processing Record 1 of Set 15 | diego de almagro
# Processing Record 2 of Set 15 | mumford
# Processing Record 3 of Set 15 | berdigestyakh
# Processing Record 4 of Set 15 | huilong
# Processing Record 5 of Set 15 | barre
# Processing Record 6 of Set 15 | kelo
# Processing Record 7 of Set 15 | ikungi
# Processing Record 8 of Set 15 | sabang
# Processing Record 9 of Set 15 | chiredzi
# Processing Record 10 of Set 15 | kalat
# Processing Record 11 of Set 15 | valea ierii
# Processing Record 12 of Set 15 | kemijarvi
# Processing Record 13 of Set 15 | asau
# Processing Record 14 of Set 15 | bilokurakyne
# Processing Record 15 of Set 15 | jalu
# Processing Record 16 of Set 15 | longonjo
# Processing Record 17 of Set 15 | powell
# Processing Record 18 of Set 15 | daniel flores
# Processing Record 19 of Set 15 | zhezkazgan
# Processing Record 20 of Set 15 | nelidovo
# Processing Record 21 of Set 15 | atyrau
# Processing Record 22 of Set 15 | gambo
# Processing Record 23 of Set 15 | mendahara
# City not found. Skipping...
# Processing Record 24 of Set 15 | naron
# Processing Record 25 of Set 15 | belyy yar
# Processing Record 26 of Set 15 | nemuro
# Processing Record 27 of Set 15 | grande-riviere
# City not found. Skipping...
# Processing Record 28 of Set 15 | lapua
# Processing Record 29 of Set 15 | touba
# Processing Record 30 of Set 15 | merritt island
# Processing Record 31 of Set 15 | fria
# Processing Record 32 of Set 15 | tiznit
# Processing Record 33 of Set 15 | banda aceh
# Processing Record 34 of Set 15 | creel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Faya      SA  18.3851   42.4509     84.72        32          54
# 1        Meulaboh      ID   4.1363   96.1285     83.89        67          93
# 2         Kinston      US  35.2627  -77.5816     71.78        94           0
# 3           Pisco      PE -13.7000  -76.2167     55.45        88         100
# 4     Henties Bay      NA -22.1160   14.2845     59.90        72           9
# 5  Cabo San Lucas      MX  22.8909 -109.9124     82.51        69           7
# 6     Provideniya      RU  64.3833 -173.3000     48.34        90          96
# 7     Teluk Intan      MY   4.0259  101.0213     87.87        60         100
# 8      Chokurdakh      RU  70.6333  147.9167     43.32        82         100
# 9            Hilo      US  19.7297 -155.0900     79.29        97         100
#
#    Wind Speed Current Description
# 0        7.61       broken clouds
# 1        7.72     overcast clouds
# 2        0.00                mist
# 3        0.00                mist
# 4        3.94           clear sky
# 5        3.00           clear sky
# 6        4.74     overcast clouds
# 7        8.21     overcast clouds
# 8       10.20     overcast clouds
# 9        3.44     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
